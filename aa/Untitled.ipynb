# %%
import pandas as pd

# %%
path='data.csv'

# %%
path
# Out:
# 'data.csv'

# %%
df=pd.read_csv(path,encoding='cp949')
df
# Out:
#      학번   이름    국어  수학  영어  과학  Unnamed: 6  Unnamed: 7  Unnamed: 8 Unnamed: 9
# 0  30202  1유현  100  80  55  55         NaN         NaN         NaN        NaN
# 1  30203  2유현   95  75  57  57         NaN         NaN         NaN        NaN
# 2  30204  3유현   90  70  59  59         NaN         NaN         NaN        NaN
# 3  30205  4유현   85  65  61  61         NaN         NaN         NaN        NaN
# 4  30206  5유현   80  60  63  63         NaN         NaN         NaN        NaN
# 5  30207  6유현   75  55  65  65         NaN         NaN         NaN        NaN
# 6  30208  7유현   70  50  67  67         NaN         NaN         NaN        NaN
# 7  30209  8유현   65  45  69  69         NaN         NaN         NaN          ㅁ
# 8  30210  9유현   60  40  71  71         NaN         NaN         NaN        NaN

# %%
df.head(3)
# Out:
#      학번   이름    국어  수학  영어  과학  Unnamed: 6  Unnamed: 7  Unnamed: 8 Unnamed: 9
# 0  30202  1유현  100  80  55  55         NaN         NaN         NaN        NaN
# 1  30203  2유현   95  75  57  57         NaN         NaN         NaN        NaN
# 2  30204  3유현   90  70  59  59         NaN         NaN         NaN        NaN

# %%
df.isnull()
# Out:
#      학번     이름      국어     수학     영어     과학  Unnamed: 6  Unnamed: 7  \
# 0  False  False  False  False  False  False        True        True
# 1  False  False  False  False  False  False        True        True
# 2  False  False  False  False  False  False        True        True
# 3  False  False  False  False  False  False        True        True
# 4  False  False  False  False  False  False        True        True
# 5  False  False  False  False  False  False        True        True
# 6  False  False  False  False  False  False        True        True
# 7  False  False  False  False  False  False        True        True
# 8  False  False  False  False  False  False        True        True
#
#    Unnamed: 8  Unnamed: 9
# 0        True        True
# 1        True        True
# 2        True        True
# 3        True        True
# 4        True        True
# 5        True        True
# 6        True        True
# 7        True       False
# 8        True        True

# %%
null_count = df.isnull().sum()

# %%
df_null_count = null_count.reset_index()

# %%
df_null_count.columns=['메뉴','결측값']

# %%
df_2=df_null_count.tail(2)
df_2
# Out:
#            메뉴  결측값
# 8  Unnamed: 8    9
# 9  Unnamed: 9    8

# %%
drop_columns=df_2['메뉴']

# %%
drop_columns
# Out:
# 8    Unnamed: 8
# 9    Unnamed: 9
# Name: 메뉴, dtype: object

# %%
drop_columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of 8    Unnamed: 8
# 9    Unnamed: 9
# Name: 메뉴, dtype: object>

# %%
df[drop_columns]
# Out:
#    Unnamed: 8 Unnamed: 9
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN
# 5         NaN        NaN
# 6         NaN        NaN
# 7         NaN          ㅁ
# 8         NaN        NaN

# %%
df.shape
# Out:
# (9, 10)

# %%
df5=df.drop(drop_columns,axis=1)

# %%
df5
# Out:
#      학번   이름    국어  수학  영어  과학  Unnamed: 6  Unnamed: 7
# 0  30202  1유현  100  80  55  55         NaN         NaN
# 1  30203  2유현   95  75  57  57         NaN         NaN
# 2  30204  3유현   90  70  59  59         NaN         NaN
# 3  30205  4유현   85  65  61  61         NaN         NaN
# 4  30206  5유현   80  60  63  63         NaN         NaN
# 5  30207  6유현   75  55  65  65         NaN         NaN
# 6  30208  7유현   70  50  67  67         NaN         NaN
# 7  30209  8유현   65  45  69  69         NaN         NaN
# 8  30210  9유현   60  40  71  71         NaN         NaN

# %%
df5.shape
# Out:
# (9, 8)
